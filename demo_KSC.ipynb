# %%
import os, sys
from obspy.core import UTCDateTime
sys.path.append('lib')
import FDSNtools
import wrappers
import SDS

import importlib
#importlib.reload(wrappers)

subnet = 'KSC'

preconfigured=True

# %%
if not preconfigured:
    # PRE-CONFIGURE CONFIGURATION
    startt = UTCDateTime(2022,8,1)
    endt = UTCDateTime(2022,12,5)
    SDS_TOP=os.path.join(os.getenv('HOME'), 'Dropbox', 'DATA', 'SDS')

    # get list of trace_ids from SDS archive
    thisSDSobj = SDS.SDSobj(SDS_TOP)
    trace_ids = thisSDSobj._sds_get_nonempty_traceids(startt, endt)
    print(trace_ids)

    for id in trace_ids:
        keepRaw = True
        sgram = False
        if id[-1] in 'ZNEF123456789' and id[-2] in 'HD':
            keepRaw = False
            if id[-1] in 'ZF4' and id[-2] in 'HD':
                sgram = True
        print(f"{id},{subnet},None,{keepRaw},{sgram}")
        # These have been appended to trace_ids config csv


# how do we create an inventory for the KSC network?
    # there is nothing to do for the well stations. they are already calibrated.
    # for the seismic and infrasound stations, we need appropriate responses for:
        # Trillum + Centaur
        # InfraBSU + Centaur
        # Chaparral M25 + Centaur
    # The shortcut is if there is no inv, just to supply calibration information from counts 2 Pa, and counts to m/s.
        # calibration info should be in the trace_ids config. would be 1 for well channels.
        # no Drs calculation if no inv.
        # but can still do CSAM and spectrograms.
        # could potentially do reduced velocity, and reduced pressure.
        # maybe the whole idea of reduced displacement is silly, and just do reduced velocity instead? or as well as?
    # TO DO:
        # add other parameters, from metrics.py. but get traditional iceweb stuff working first.

# %%
# RUN JOB
# call the wrapper
#os.system('rm /Users/thompsong/IceWeb/*.db')
importlib.reload(wrappers)
wrappers.run_iceweb_job('KSC', configdir='config', configname='laptop' )
# Out:
# Timewindow:  2022-09-14T00:00:00.000000Z 2022-12-01T00:00:00.000000Z
# /Users/thompsong/Dropbox/DATA/SDS/metadata/28.608389_-80.604333_20220914_20221201_0.18099547511312217.sml does not exist
# sqlite version: 2.6.0
#
#
# Time now: 2023-10-30T21:09:21.180101
# Processing 2022-09-14T00:00:00.000000Z
# Inserted new row for KSC_2022-09-14T00:00:00_2022-09-14T01:00:00
# Got a lock on KSC_2022-09-14T00:00:00_2022-09-14T01:00:00
#
#
# Time now: 2023-10-30T21:09:23.489095
# ('KSC', '2022-09-14T00:00:00', '2022-09-14T01:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-09-14T00:00:00_2022-09-14T01:00:00
# ('KSC', '2022-09-14T00:00:00', '2022-09-14T01:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.BCHH4.00.HD2 absolute= True
# FL.BCHH4.00.HD3 absolute= True
# FL.BCHH4.00.HDF absolute= True
# FL.BCHH4.10.HHE absolute= True
# FL.BCHH4.10.HHN absolute= True
# FL.BCHH4.10.HHZ absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# /Users/thompsong/Documents/GitHub/tremorExplorer/lib/IceWeb.py:455: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([original_df, df], ignore_index=True)
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD2_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD3_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# 6I.0XXXX.XX.HDH absolute= False
# 6I.12264.29.HDD absolute= False
# 6I.21498.82.HDD absolute= False
# 6I.21516.91.HDD absolute= False
# 6I.21516.92.BDD absolute= False
# 6S.02374.88.HDH absolute= False
# 6S.12264.19.HDD absolute= False
# 6S.12264.20.HDD absolute= False
# 6S.12264.21.HDD absolute= False
# 6S.12264.23.BDD absolute= False
# Saving to ./RSAM_metrics_6I.0XXXX.XX.HDH_2022.csv
# Saving to ./RSAM_metrics_6I.12264.29.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21498.82.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.91.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.92.BDD_2022.csv
# Saving to ./RSAM_metrics_6S.02374.88.HDH_2022.csv
# Saving to ./RSAM_metrics_6S.12264.19.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.20.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.21.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.23.BDD_2022.csv
# ('KSC', '2022-09-14T00:00:00', '2022-09-14T01:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-09-14T00:00:00_2022-09-14T01:00:00 unlocked
# ('KSC', '2022-09-14T00:00:00', '2022-09-14T01:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-09-14T00:00:00_2022-09-14T01:00:00 was not locked
#
#
# Time now: 2023-10-30T21:09:39.050909
# Processing 2022-09-14T01:00:00.000000Z
# Inserted new row for KSC_2022-09-14T01:00:00_2022-09-14T02:00:00
# Got a lock on KSC_2022-09-14T01:00:00_2022-09-14T02:00:00
#
#
# Time now: 2023-10-30T21:09:39.886413
# ('KSC', '2022-09-14T01:00:00', '2022-09-14T02:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-09-14T01:00:00_2022-09-14T02:00:00
# ('KSC', '2022-09-14T01:00:00', '2022-09-14T02:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.BCHH4.00.HD2 absolute= True
# FL.BCHH4.00.HD3 absolute= True
# FL.BCHH4.00.HDF absolute= True
# FL.BCHH4.10.HHE absolute= True
# FL.BCHH4.10.HHN absolute= True
# FL.BCHH4.10.HHZ absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD2_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD3_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# 6I.0XXXX.XX.HDH absolute= False
# 6I.12264.29.HDD absolute= False
# 6I.21498.82.HDD absolute= False
# 6I.21516.91.HDD absolute= False
# 6I.21516.92.BDD absolute= False
# 6S.02374.88.HDH absolute= False
# 6S.12264.19.HDD absolute= False
# 6S.12264.20.HDD absolute= False
# 6S.12264.21.HDD absolute= False
# 6S.12264.23.BDD absolute= False
# Saving to ./RSAM_metrics_6I.0XXXX.XX.HDH_2022.csv
# Saving to ./RSAM_metrics_6I.12264.29.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21498.82.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.91.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.92.BDD_2022.csv
# Saving to ./RSAM_metrics_6S.02374.88.HDH_2022.csv
# Saving to ./RSAM_metrics_6S.12264.19.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.20.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.21.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.23.BDD_2022.csv
# ('KSC', '2022-09-14T01:00:00', '2022-09-14T02:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-09-14T01:00:00_2022-09-14T02:00:00 unlocked
# ('KSC', '2022-09-14T01:00:00', '2022-09-14T02:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-09-14T01:00:00_2022-09-14T02:00:00 was not locked
#
#
# Time now: 2023-10-30T21:09:55.262187
# Processing 2022-09-14T02:00:00.000000Z
# Inserted new row for KSC_2022-09-14T02:00:00_2022-09-14T03:00:00
# Got a lock on KSC_2022-09-14T02:00:00_2022-09-14T03:00:00
#
#
# Time now: 2023-10-30T21:09:56.034392
# ('KSC', '2022-09-14T02:00:00', '2022-09-14T03:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-09-14T02:00:00_2022-09-14T03:00:00
# ('KSC', '2022-09-14T02:00:00', '2022-09-14T03:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.BCHH4.00.HD2 absolute= True
# FL.BCHH4.00.HD3 absolute= True
# FL.BCHH4.00.HDF absolute= True
# FL.BCHH4.10.HHE absolute= True
# FL.BCHH4.10.HHN absolute= True
# FL.BCHH4.10.HHZ absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD2_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD3_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# 6I.0XXXX.XX.HDH absolute= False
# 6I.12264.29.HDD absolute= False
# 6I.21498.82.HDD absolute= False
# 6I.21516.91.HDD absolute= False
# 6I.21516.92.BDD absolute= False
# 6S.02374.88.HDH absolute= False
# 6S.12264.19.HDD absolute= False
# 6S.12264.20.HDD absolute= False
# 6S.12264.21.HDD absolute= False
# 6S.12264.23.BDD absolute= False
# Saving to ./RSAM_metrics_6I.0XXXX.XX.HDH_2022.csv
# Saving to ./RSAM_metrics_6I.12264.29.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21498.82.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.91.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.92.BDD_2022.csv
# Saving to ./RSAM_metrics_6S.02374.88.HDH_2022.csv
# Saving to ./RSAM_metrics_6S.12264.19.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.20.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.21.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.23.BDD_2022.csv
# ('KSC', '2022-09-14T02:00:00', '2022-09-14T03:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-09-14T02:00:00_2022-09-14T03:00:00 unlocked
# ('KSC', '2022-09-14T02:00:00', '2022-09-14T03:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-09-14T02:00:00_2022-09-14T03:00:00 was not locked
#
#
# Time now: 2023-10-30T21:10:11.719390
# Processing 2022-09-14T03:00:00.000000Z
# Inserted new row for KSC_2022-09-14T03:00:00_2022-09-14T04:00:00
# Got a lock on KSC_2022-09-14T03:00:00_2022-09-14T04:00:00
#
#
# Time now: 2023-10-30T21:10:12.632389
# ('KSC', '2022-09-14T03:00:00', '2022-09-14T04:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-09-14T03:00:00_2022-09-14T04:00:00
# ('KSC', '2022-09-14T03:00:00', '2022-09-14T04:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.BCHH4.00.HD2 absolute= True
# FL.BCHH4.00.HD3 absolute= True
# FL.BCHH4.00.HDF absolute= True
# FL.BCHH4.10.HHE absolute= True
# FL.BCHH4.10.HHN absolute= True
# FL.BCHH4.10.HHZ absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD2_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD3_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# 6I.0XXXX.XX.HDH absolute= False
# 6I.12264.29.HDD absolute= False
# 6I.21498.82.HDD absolute= False
# 6I.21516.91.HDD absolute= False
# 6I.21516.92.BDD absolute= False
# 6S.02374.88.HDH absolute= False
# 6S.12264.19.HDD absolute= False
# 6S.12264.20.HDD absolute= False
# 6S.12264.21.HDD absolute= False
# 6S.12264.23.BDD absolute= False
# Saving to ./RSAM_metrics_6I.0XXXX.XX.HDH_2022.csv
# Saving to ./RSAM_metrics_6I.12264.29.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21498.82.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.91.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.92.BDD_2022.csv
# Saving to ./RSAM_metrics_6S.02374.88.HDH_2022.csv
# Saving to ./RSAM_metrics_6S.12264.19.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.20.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.21.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.23.BDD_2022.csv
# ('KSC', '2022-09-14T03:00:00', '2022-09-14T04:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-09-14T03:00:00_2022-09-14T04:00:00 unlocked
# ('KSC', '2022-09-14T03:00:00', '2022-09-14T04:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-09-14T03:00:00_2022-09-14T04:00:00 was not locked
#
#
# Time now: 2023-10-30T21:10:28.311949
# Processing 2022-09-14T04:00:00.000000Z
# Inserted new row for KSC_2022-09-14T04:00:00_2022-09-14T05:00:00
# Got a lock on KSC_2022-09-14T04:00:00_2022-09-14T05:00:00
#
#
# Time now: 2023-10-30T21:10:29.199277
# ('KSC', '2022-09-14T04:00:00', '2022-09-14T05:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-09-14T04:00:00_2022-09-14T05:00:00
# ('KSC', '2022-09-14T04:00:00', '2022-09-14T05:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.BCHH4.00.HD2 absolute= True
# FL.BCHH4.00.HD3 absolute= True
# FL.BCHH4.00.HDF absolute= True
# FL.BCHH4.10.HHE absolute= True
# FL.BCHH4.10.HHN absolute= True
# FL.BCHH4.10.HHZ absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD2_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HD3_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.00.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.BCHH4.10.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to ./RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# 6I.0XXXX.XX.HDH absolute= False
# 6I.12264.29.HDD absolute= False
# 6I.21498.82.HDD absolute= False
# 6I.21516.91.HDD absolute= False
# 6I.21516.92.BDD absolute= False
# 6S.02374.88.HDH absolute= False
# 6S.12264.19.HDD absolute= False
# 6S.12264.20.HDD absolute= False
# 6S.12264.21.HDD absolute= False
# 6S.12264.23.BDD absolute= False
# Saving to ./RSAM_metrics_6I.0XXXX.XX.HDH_2022.csv
# Saving to ./RSAM_metrics_6I.12264.29.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21498.82.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.91.HDD_2022.csv
# Saving to ./RSAM_metrics_6I.21516.92.BDD_2022.csv
# Saving to ./RSAM_metrics_6S.02374.88.HDH_2022.csv
# Saving to ./RSAM_metrics_6S.12264.19.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264.20.HDD_2022.csv
# Saving to ./RSAM_metrics_6S.12264