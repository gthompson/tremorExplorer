# %%
import sys
sys.path.append('lib')
import IceWeb
from obspy import UTCDateTime
startt = UTCDateTime(2022,8,1)
endt = UTCDateTime(2022,8,2)
SDS_TOP='.'

# %%
r = IceWeb.RSAMobj()
r.read(startt, endt, SDS_TOP, corrected=True)
r.plot()
# Out:
# 24 Trace(s) in Stream:
#
# FL.BCHH2.10.HD4 | 2022-08-01T00:00:00.000000Z - 2022-08-02T00:00:00.000000Z | 60.0 s, 1441 samples
# ...
# (22 other traces)
# ...
# 6S.12264.23.BDD | 2022-08-01T03:59:00.000000Z - 2022-08-01T03:59:00.000000Z | 60.0 s, 1 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# [15.652910259945394, 8.648542924472169, 15.657750709088644, 3.16777535103239, 840813.4471999999, 6513106475.2, 1646727.2709333333, 2457902.6789333336, 803683.5045333334, 2304066.0626666667, 18042.892799999998, 30685.028486666666, 1975268901.3333335, 1533276872337640.5, 1865171519422745.2, 1077256548476768.8, 684494827671.6666, 832138658417.6666, 862232548138.3334, 6291.793519999999, 3338345465271.0, 839472443255.3334, 6457130314904.333, 35574505.946779996]
# ...
